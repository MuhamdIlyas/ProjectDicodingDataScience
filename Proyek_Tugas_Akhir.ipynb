# %% [markdown]
# \# Proyek Analisis Data: E-Commerce Public Dataset
# - Nama:Muhamad Ilyas
# - Email:181240000831@unisnu.ac.id
# - Id Dicoding:

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana performa penjualan dan payment Value dalam bebebrapa bulan terakhir ?
# - Produk apa yang paling banyak dan paling sedikit dicari ?

# %% [markdown]
# ## Menyaipkan semua library yang dibutuhkan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# **Table Customer Dataset**

# %%
customer_url = 'https://raw.githubusercontent.com/MuhamdIlyas/ProjectDicodingDataScience/master/E-Commerce_Public_Dataset/customers_dataset.csv'
customer = pd.read_csv(customer_url)
customer.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# **Table Geolocation Dataset**

# %%
geolocation_url = 'https://raw.githubusercontent.com/MuhamdIlyas/ProjectDicodingDataScience/master/E-Commerce_Public_Dataset/geolocation_dataset.csv'
geolocation = pd.read_csv(geolocation_url)
geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %% [markdown]
# **Table Order Item Dataset**

# %%
order_item_url = 'https://raw.githubusercontent.com/MuhamdIlyas/ProjectDicodingDataScience/master/E-Commerce_Public_Dataset/order_items_dataset.csv'
order_item = pd.read_csv(order_item_url)
order_item.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %% [markdown]
# **Table Order Payment Dataset**

# %%
order_payment_url = 'https://raw.githubusercontent.com/MuhamdIlyas/ProjectDicodingDataScience/master/E-Commerce_Public_Dataset/order_payments_dataset.csv'
order_payment = pd.read_csv(order_payment_url)
order_payment.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %% [markdown]
# **Table Order Reviews Dataset**

# %%
order_reviews_url = 'https://raw.githubusercontent.com/MuhamdIlyas/ProjectDicodingDataScience/master/E-Commerce_Public_Dataset/order_reviews_dataset.csv'
order_reviews = pd.read_csv(order_reviews_url)
order_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %% [markdown]
# **Table Order Dataset**

# %%
order_url = 'https://raw.githubusercontent.com/MuhamdIlyas/ProjectDicodingDataScience/master/E-Commerce_Public_Dataset/orders_dataset.csv'
order = pd.read_csv(order_url)
order.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# **Table Poduct Category Name**

# %%
product_category_url = 'https://raw.githubusercontent.com/MuhamdIlyas/ProjectDicodingDataScience/master/E-Commerce_Public_Dataset/product_category_name_translation.csv'
product_category = pd.read_csv(product_category_url)
product_category.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# **Table Product Dataset**

# %%
product_url = 'https://raw.githubusercontent.com/MuhamdIlyas/ProjectDicodingDataScience/master/E-Commerce_Public_Dataset/products_dataset.csv'
product = pd.read_csv(product_url)
product.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %% [markdown]
# **Table Seller Dataset**

# %%
seller_url = 'https://raw.githubusercontent.com/MuhamdIlyas/ProjectDicodingDataScience/master/E-Commerce_Public_Dataset/sellers_dataset.csv'
seller = pd.read_csv(seller_url)
seller.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# **Info Customer**

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %% [markdown]
# **Memeriksa Data Duplikasi**

# %%
print("Jumlah Duplikasi :", customer.duplicated().sum())
# Out:
# Jumlah Duplikasi : 0

# %% [markdown]
# **Pemeriksaan Menggunakan Describe()**

# %%
customer.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# **Info Geolocation**

# %%
geolocation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %% [markdown]
# **Memeriksa Data Duplikasi**

# %%
print("Jumlah DUplikasi :", geolocation.duplicated().sum())
# Out:
# Jumlah DUplikasi : 261831

# %% [markdown]
# **Memeriksa Menggunakan Describe**

# %%
geolocation.describe()
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %% [markdown]
# **Info Order_Item**

# %%
order_item.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %% [markdown]
# **Memeriksa Data Duplikasi**

# %%
print("Jumlah Duplikasi :", order_item.duplicated().sum())
# Out:
# Jumlah Duplikasi : 0

# %% [markdown]
# **Pemeriksaan Menggunakan Describe**

# %%
order_item.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# **Info Order Payment**

# %%
order_payment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %% [markdown]
# **Mengecek Data Duplikasi**

# %%
print("Jumlah Data Duplikas :", order_payment.duplicated().sum())
# Out:
# Jumlah Data Duplikas : 0

# %% [markdown]
# **Pemeriksaan Menggunakan Describe**

# %%
order_payment.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %% [markdown]
# **Info Order Reviews**

# %%
order_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %% [markdown]
# **Melihat Missing Value**

# %%
order_reviews.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %% [markdown]
# **Memeriksa Data Duplikasi**

# %%
print('Jumlah Duplikasi :', order_reviews.duplicated().sum())
# Out:
# Jumlah Duplikasi : 0

# %% [markdown]
# **Memeriksa Menggunkan Describe**

# %%
order_reviews.describe()
# Out:
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %% [markdown]
# **Info Order**

# %%
order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %% [markdown]
# **Melihat Missing Value**

# %%
order.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# **Melihat Data Duplikasi**

# %%
print("JUmlah Duplikasi :", order.duplicated().sum())
# Out:
# JUmlah Duplikasi : 0

# %% [markdown]
# **Memeriksa Menggunakan Describe**

# %%
order.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %% [markdown]
# **Info Product Category**

# %%
product_category.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %% [markdown]
# **Melihat Data Duplikasi**

# %%
print("Jumlah Duplikasi :", product_category.duplicated().sum())
# Out:
# Jumlah Duplikasi : 0

# %% [markdown]
# **Memeriksa Menggunakan Describe**

# %%
product_category.describe()
# Out:
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %% [markdown]
# **Info Product**

# %%
product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# **Memeriksa Missing Value**

# %%
order.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# **Memeriksa Data Duplikasi**

# %%
print("JUmlah Duplikasi :", order.duplicated().sum())
# Out:
# JUmlah Duplikasi : 0

# %% [markdown]
# **Memeriksa Menggunakan Describe**

# %%
order.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %% [markdown]
# **Info Seller**

# %%
seller.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %% [markdown]
# **Memeriksa Data Duplikasi**

# %%
print("Jumlah Duplikasi :", seller.duplicated().sum())
# Out:
# Jumlah Duplikasi : 0

# %% [markdown]
# **Memeriksa Dengan Describe**

# %%
seller.describe()
# Out:
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# **Membersihkan Data Geolocation Duplikasi**

# %%
geolocation.drop_duplicates(inplace=True)

# %% [markdown]
# Memeriksa Duplikasi

# %%
print("Jumlah Duplikasi :", geolocation.duplicated().sum())
# Out:
# Jumlah Duplikasi : 0

# %% [markdown]
# **Membersihkan Inaccurate Order Item**

# %% [markdown]
# Memfilter inaccurate value pada kolom price.

# %%
order_item[order_item.price == order_item.price.min()]
# Out:
#                                order_id  order_item_id  \
# 27652  3ee6513ae7ea23bdfab5b9ab60bffcb5              1
# 48625  6e864b3f0ec71031117ad4cf46b7f2a1              1
# 87081  c5bdd8ef3c0ec420232e668302179113              2
#
#                              product_id                         seller_id  \
# 27652  8a3254bee785a526d548a81a9bc3c9be  96804ea39d96eb908e7c3afdb671bb9e
# 48625  8a3254bee785a526d548a81a9bc3c9be  96804ea39d96eb908e7c3afdb671bb9e
# 87081  8a3254bee785a526d548a81a9bc3c9be  96804ea39d96eb908e7c3afdb671bb9e
#
#        shipping_limit_date  price  freight_value
# 27652  2018-05-04 03:55:26   0.85          18.23
# 48625  2018-05-02 20:30:34   0.85          18.23
# 87081  2018-05-07 02:55:22   0.85          22.30

# %% [markdown]
# Mengganti harga 0.85 menjadi harga 85

# %%
order_item.price.replace(order_item.price.min(), 85, inplace=True)

# %% [markdown]
# Memeriksa Hasil dari replace

# %%
order_item[order_item.price == order_item.price.min()]
# Out:
#                                order_id  order_item_id  \
# 57297  8272b63d03f5f79c56e9e4120aec44ef              1
# 57298  8272b63d03f5f79c56e9e4120aec44ef              2
# 57299  8272b63d03f5f79c56e9e4120aec44ef              3
# 57300  8272b63d03f5f79c56e9e4120aec44ef              4
# 57301  8272b63d03f5f79c56e9e4120aec44ef              5
# 57302  8272b63d03f5f79c56e9e4120aec44ef              6
# 57303  8272b63d03f5f79c56e9e4120aec44ef              7
# 57304  8272b63d03f5f79c56e9e4120aec44ef              8
# 57305  8272b63d03f5f79c56e9e4120aec44ef              9
# 57306  8272b63d03f5f79c56e9e4120aec44ef             10
# 57307  8272b63d03f5f79c56e9e4120aec44ef             11
# 57308  8272b63d03f5f79c56e9e4120aec44ef             12
# 57309  8272b63d03f5f79c56e9e4120aec44ef             13
# 57310  8272b63d03f5f79c56e9e4120aec44ef             14
# 57311  8272b63d03f5f79c56e9e4120aec44ef             15
# 57312  8272b63d03f5f79c56e9e4120aec44ef             16
# ...

# %% [markdown]
# Mengecek Inaccurate dengan describe

# %%
order_item.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.655980      19.990320
# std         0.705124     183.632979      15.806405
# min         1.000000       1.200000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# **Membersihkan Missing Value pada order reviews**

# %% [markdown]
# Melihat data yang mengandung missing value, Untuk Review Comment tetap di Keep karena pendapat setiap orang berbeda-beda

# %%
order_reviews[order_reviews.review_comment_title.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %% [markdown]
# **Membersihkan Missing Value pada Order**

# %%
order[order.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %% [markdown]
# Mengisi kolom order_approved_at dengan order_purchase_timestamp

# %%
order["order_approved_at"] = order["order_purchase_timestamp"]

# %% [markdown]
# Mengisi kolom order_delivered_carrier_date dengan order_purchase_timestamp

# %%
order["order_delivered_carrier_date"] = order["order_purchase_timestamp"]

# %% [markdown]
# Mengisi kolom order_delivered_customer_date dengan order_purchase_timestamp

# %%
order["order_delivered_customer_date"].fillna(value='order_purchase_timestamp', inplace=True)

# %% [markdown]
# Mengecek Missing Value

# %%
order.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# **Membersihkan Data Product**

# %% [markdown]
# Melihat Nama Kategori Produk

# %%
product.product_category_name.value_counts()
# Out:
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: product_category_name, Length: 73, dtype: int64

# %% [markdown]
# Mengisi Missing Value Berdasarkan nilai yang dominan

# %%
product.fillna(value="cama_mesa_banho", inplace=True)

# %% [markdown]
# **Mengecek Missing Value**

# %%
product.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore Data Seller dan Order Item

# %% [markdown]
# Melihat informasi keseluruhan pada seller

# %%
seller.describe(include='all')
# Out:
#                                seller_id  seller_zip_code_prefix seller_city  \
# count                               3095             3095.000000        3095
# unique                              3095                     NaN         611
# top     3442f8959a84dea7ee197c632cb2df15                     NaN   sao paulo
# freq                                   1                     NaN         694
# mean                                 NaN            32291.059451         NaN
# std                                  NaN            32713.453830         NaN
# min                                  NaN             1001.000000         NaN
# 25%                                  NaN             7093.500000         NaN
# 50%                                  NaN            14940.000000         NaN
# 75%                                  NaN            64552.500000         NaN
# max                                  NaN            99730.000000         NaN
#
#        seller_state
# count          3095
# ...

# %% [markdown]
# Melihat Informasi Keseluruhan pada order_item

# %%
order_item.describe(include='all')
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# std                                  NaN       0.705124
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %% [markdown]
# Mengecek Harga dari terendah ke termahal

# %%
order_item.sort_values(by='price', ascending=True)
# Out:
#                                 order_id  order_item_id  \
# 57312   8272b63d03f5f79c56e9e4120aec44ef             16
# 57305   8272b63d03f5f79c56e9e4120aec44ef              9
# 57304   8272b63d03f5f79c56e9e4120aec44ef              8
# 57308   8272b63d03f5f79c56e9e4120aec44ef             12
# 57309   8272b63d03f5f79c56e9e4120aec44ef             13
# ...                                  ...            ...
# 11249   199af31afc78c699f0dbf71fb178d4d4              1
# 74336   a96610ab360d42a2e5335a3998b4718a              1
# 107841  f5136e38d1a14a4dbd87dff67da82701              1
# 112233  fefacc66af859508bf1a7934eab1e97f              1
# 3556    0812eb902a67711a1cb742b3cdaa65ae              1
#
#                               product_id                         seller_id  \
# 57312   270516a3f41dc035aa87d220228f844c  2709af9587499e95e803a6498a5a56e9
# 57305   05b515fdc76e888aada3c6d66c201dff  2709af9587499e95e803a6498a5a56e9
# ...

# %% [markdown]
# Merge antara tabel order_item dan seller

# %%
order_seller = pd.merge(
    left=order_item,
    right=seller,
    how='left',
    left_on="seller_id",
    right_on="seller_id"
)
order_seller.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value  seller_zip_code_prefix  \
# 0  2017-09-19 09:45:35   58.90          13.29                   27277
# 1  2017-05-03 11:05:13  239.90          19.93                    3471
# ...

# %% [markdown]
# Melihat Informasi Keseluruhan pada order_seller

# %%
order_seller.describe(include='all')
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# std                                  NaN       0.705124
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %% [markdown]
# pivot Table untuk melihat Persebaran produk berdasarkan kota

# %%
order_seller.groupby(by="seller_city").agg({
    "order_id" : "nunique",
    "seller_zip_code_prefix" : ["max", "min", "mean","std"]
})
# Out:
#                 order_id seller_zip_code_prefix
#                  nunique                    max    min          mean       std
# seller_city
# 04482255               1                  22790  22790  22790.000000       NaN
# abadia de goias        1                  75345  75345  75345.000000       NaN
# afonso claudio         5                  29600  29600  29600.000000  0.000000
# aguas claras df        1                  71900  71900  71900.000000       NaN
# alambari               5                  18220  18220  18220.000000  0.000000
# ...                  ...                    ...    ...           ...       ...
# volta redonda        143                  27277  27274  27276.903846  0.530111
# votorantim           207                  18111  18110  18110.015267  0.122848
# votuporanga          132                  15505  15500  15501.956522  0.551965
# xanxere                8                  89820  89820  89820.000000  0.000000
# ...

# %% [markdown]
# Persebaran jumlah pelanggan berdasarkan kota dan negara bagian dengan method groupby() dan mengurutkannya nilainya menggunakan method sort_values() secara descending

# %%
order_seller.groupby(by="seller_city").order_id.nunique().sort_values(ascending=False)
# Out:
# seller_city
# sao paulo         24588
# ibitinga           6565
# curitiba           2722
# santo andre        2711
# belo horizonte     2414
#                   ...
# ivoti                 1
# sao paulo sp          1
# janauba               1
# jarinu                1
# 04482255              1
# Name: order_id, Length: 611, dtype: int64

# %%
order_seller.groupby(by="seller_state").order_id.nunique().sort_values(ascending=False)
# Out:
# seller_state
# SP    70188
# MG     7930
# PR     7673
# RJ     4353
# SC     3667
# RS     1989
# DF      824
# BA      569
# GO      463
# PE      406
# MA      392
# ES      318
# MT      137
# CE       91
# RN       51
# MS       49
# PB       36
# RO       14
# PI       12
# SE        9
# PA        8
# AM        3
# AC        1
# Name: order_id, dtype: int64

# %% [markdown]
# ### Explore Order Payment

# %% [markdown]
# Melihat Informasi Keseluruhan pada order_payment

# %%
order_payment.describe(include='all')
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# ...

# %% [markdown]
# Merge antara tabel order_payment dan order_seller

# %%
order_seller_payement = pd.merge(
    left=order_payment,
    right=order_seller,
    how='left',
    left_on="order_id",
    right_on="order_id"
)
order_seller_payement.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value  order_item_id  \
# 0                     8          99.33            1.0
# 1                     1          24.39            1.0
# 2                     1          65.71            1.0
# 3                     8         107.78            1.0
# 4                     2         128.45            1.0
#
#                          product_id                         seller_id  \
# 0  af74cc53dcffc8384b29e7abfa41902b  213b25e6f54661939f11710a6fddb871
# 1  a630cc320a8c872f9de830cf121661a3  eaf6d55068dea77334e8477d3878d89e
# ...

# %% [markdown]
# ### Explore Product

# %% [markdown]
# Melihat Informasi Keseluruhan pada product

# %%
product.describe(include='all')
# Out:
#                               product_id product_category_name  \
# count                              32951                 32951
# unique                             32951                    73
# top     1e9e8ef04dbcff4541ed26657ea517e5       cama_mesa_banho
# freq                                   1                  3639
#
#         product_name_lenght product_description_lenght  product_photos_qty  \
# count               32951.0                      32951             32951.0
# unique                 67.0                       2961                20.0
# top                    60.0            cama_mesa_banho                 1.0
# freq                 2182.0                        610             16489.0
#
#         product_weight_g  product_length_cm  product_height_cm  \
# count            32951.0            32951.0            32951.0
# unique            2205.0              100.0              103.0
# top                200.0               16.0               10.0
# ...

# %% [markdown]
# Merge antara tabel order_seller_payement dan order_seller_payement

# %%
order_seller_payment_product = pd.merge(
    left=order_seller_payement,
    right=product,
    how='left',
    left_on="product_id",
    right_on="product_id"
)
order_seller_payment_product.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value  order_item_id  \
# 0                     8          99.33            1.0
# 1                     1          24.39            1.0
# 2                     1          65.71            1.0
# 3                     8         107.78            1.0
# 4                     2         128.45            1.0
#
#                          product_id                         seller_id  \
# 0  af74cc53dcffc8384b29e7abfa41902b  213b25e6f54661939f11710a6fddb871
# 1  a630cc320a8c872f9de830cf121661a3  eaf6d55068dea77334e8477d3878d89e
# ...

# %% [markdown]
# Pivot Table untuk informasi penjualan berdasarkan nama Jumlah Product

# %%
order_seller_payment_product.groupby(by="product_photos_qty").agg({
    "product_id": "nunique",
    "freight_value": "sum",
    "price":  "sum"
}).sort_values(by="price", ascending=False)
# Out:
#                     product_id  freight_value       price
# product_photos_qty
# 1.0                      16489     1168905.54  6651031.88
# 2.0                       6263      448336.62  2562685.64
# 3.0                       3860      259391.79  1754336.16
# 4.0                       2428      183933.10  1294951.57
# 5.0                       1484      119895.70   769219.90
# 6.0                        968       75864.98   516697.56
# 7.0                        343       33617.48   247196.73
# cama_mesa_banho            610       30618.68   190956.59
# 8.0                        192       16695.34   114559.00
# 10.0                        95        9382.88    53047.61
# 9.0                        105        7174.03    41106.56
# 11.0                        46        1412.85     5472.16
# 12.0                        35        1060.81     2741.46
# 14.0                         5          97.98     1500.87
# 13.0                         9         426.90     1236.78
# ...

# %% [markdown]
# ### Explore Order dan Customer

# %% [markdown]
# Melihat Informasi Keseluruhan pada Order

# %%
order.describe(include='all')
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99441
# unique            8                    98875                98875
# top       delivered      2018-04-11 10:48:14  2018-04-11 10:48:14
# freq          96478                        3                    3
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         99441                         99441
# unique                        98875                         95665
# ...

# %% [markdown]
# Melihat Informasi Keseluruhan pada Order

# %%
customer.describe(include='all')
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %% [markdown]
# Merge antara tabel customer dengan order

# %%
order_customer = pd.merge(
    left=customer,
    right=order,
    how='left',
    left_on="customer_id",
    right_on="customer_id"
)
order_customer.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %% [markdown]
# Merge antara tabel order_seller_payment_product dengan  order_customer

# %%
all_dataset = pd.merge(
    left=order_seller_payment_product,
    right=order_customer,
    how='left',
    left_on="order_id",
    right_on="order_id"
)
all_dataset.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value  order_item_id  \
# 0                     8          99.33            1.0
# 1                     1          24.39            1.0
# 2                     1          65.71            1.0
# 3                     8         107.78            1.0
# 4                     2         128.45            1.0
#
#                          product_id                         seller_id  \
# 0  af74cc53dcffc8384b29e7abfa41902b  213b25e6f54661939f11710a6fddb871
# 1  a630cc320a8c872f9de830cf121661a3  eaf6d55068dea77334e8477d3878d89e
# ...

# %%
all_dataset.groupby(by="order_status").customer_id.nunique().sort_values(ascending=False)
# Out:
# order_status
# delivered      96477
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: customer_id, dtype: int64

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana performa penjualan dan payment value dalam beberapa bulan terakhir ?

# %%
all_dataset['order_approved_at'] = pd.to_datetime(all_dataset['order_approved_at'], format= '%Y-%m')

# %% [markdown]
# Mengatur kolom dengan menggunakan set_index

# %%
all_dataset_index = all_dataset.set_index('order_approved_at')
all_dataset_index.head()
# Out:
#                                              order_id  payment_sequential  \
# order_approved_at
# 2018-04-25 22:01:49  b81ef226f3fe1789b1e8b2acac839d17                   1
# 2018-06-26 11:01:38  a9810da82917af2d9aefd1278f1dcfa0                   1
# 2017-12-12 11:19:55  25e8ea4e93396b6fa0d3dd708e76c1bd                   1
# 2017-12-06 12:04:06  ba78997921bbcdc1373bb41e913ab953                   1
# 2018-05-21 13:59:17  42fdf880ba16b47b59251dd489d4441a                   1
#
#                     payment_type  payment_installments  payment_value  \
# order_approved_at
# 2018-04-25 22:01:49  credit_card                     8          99.33
# 2018-06-26 11:01:38  credit_card                     1          24.39
# 2017-12-12 11:19:55  credit_card                     1          65.71
# 2017-12-06 12:04:06  credit_card                     8         107.78
# 2018-05-21 13:59:17  credit_card                     2         128.45
#
# ...

# %% [markdown]
# Menggunakan method **resample** untuk mengubah frekuensi atau melakukan resampling terhadap DataFrame yang memiliki komponen time series

# %%
all_time_dataset = all_dataset.resample(rule='M', on='order_approved_at').agg({
    "order_id": "nunique",
    "price": "sum"
})

all_time_dataset.index = all_time_dataset.index.strftime('%Y-%m-%d') #mengubah format order date menjadi nama bulan
all_time_dataset = all_time_dataset.reset_index()
all_time_dataset.rename(columns={
    "order_id": "order_count",
    "price": "revenue"
}, inplace=True)
all_time_dataset.head()
# Out:
#   order_approved_at  order_count    revenue
# 0        2016-09-30            3     132.39
# 1        2016-10-31          324   50942.23
# 2        2016-11-30            0       0.00
# 3        2016-12-31            1      10.90
# 4        2017-01-31          800  128637.99

# %% [markdown]
# Memvisualisasikan data dengan linechart

# %%
all_time_dataset = all_dataset.resample(rule='M', on='order_approved_at').agg({
    "order_id": "nunique",
    "price": "sum"
})

all_time_dataset.index = all_time_dataset.index.strftime('%Y-%m') #mengubah format order date menjadi nama bulan
all_time_dataset = all_time_dataset.reset_index()
all_time_dataset.rename(columns={
    "order_id": "order_count",
    "price": "revenue"
}, inplace=True)

plt.figure(figsize=(10, 5))
plt.plot(all_time_dataset["order_approved_at"], all_time_dataset["order_count"], marker='o', linewidth=2, color="blue")
plt.title("Number of Orders per Month", loc="center", fontsize=20)
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Produk apa yang paling banyak dan paling sedikit dicari ?

# %% [markdown]
# Membuat DataFrame baru untuk menampung informasi terkait jumlah penjualan tiap produk

# %%
sum_order = all_dataset.groupby("product_category_name").product_id.nunique().sort_values(ascending=False).reset_index()
sum_order.head(15)
# Out:
#           product_category_name  product_id
# 0               cama_mesa_banho        3639
# 1                 esporte_lazer        2867
# 2              moveis_decoracao        2657
# 3                  beleza_saude        2444
# 4         utilidades_domesticas        2335
# 5                    automotivo        1900
# 6        informatica_acessorios        1639
# 7                    brinquedos        1411
# 8            relogios_presentes        1329
# 9                     telefonia        1134
# 10                        bebes         919
# 11                   perfumaria         868
# 12  fashion_bolsas_e_acessorios         849
# 13                    papelaria         849
# 14                   cool_stuff         789

# %%
sum_order = all_dataset.groupby("product_category_name").product_id.nunique().sort_values(ascending=True).reset_index()
sum_order.head(15)
# Out:
#                             product_category_name  product_id
# 0                               cds_dvds_musicais           1
# 1                              seguros_e_servicos           2
# 2                                        pc_gamer           3
# 3                   fashion_roupa_infanto_juvenil           5
# 4                                 casa_conforto_2           5
# 5                        tablets_impressao_imagem           9
# 6   portateis_cozinha_e_preparadores_de_alimentos          10
# 7                                      la_cuisine          10
# 8                       moveis_colchao_e_estofado          10
# 9                                 fraldas_higiene          12
# 10                                         flores          14
# 11                             artes_e_artesanato          19
# 12                                fashion_esporte          19
# 13                              artigos_de_festas          26
# ...

# %% [markdown]
# Membuat Visualisasi data dengan Subplots

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(26, 6))

colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="product_id", y="product_category_name", data=sum_order.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best Performing Product", loc="center", fontsize=15)
ax[0].tick_params(axis ='y', labelsize=12)

sns.barplot(x="product_id", y="product_category_name", data=sum_order.sort_values(by="product_id", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Worst Performing Product", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)

plt.suptitle("Best and Worst Performing Product", fontsize=20)
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# **Bagaimana performa penjualan dan payment Value dalam beberapa bulan terakhir ?**
# - Performa Penjualan beberapa bulan terakhir sangat fluktuatif akan tetapi untuk bulan erakhir mengalami penurunan yang sangat tajam.
#
# **Produk apa yang paling banyak dan paling sedikit dicari ?**
# - Produk yang paling banyak dicari adalah **cama mesa banho** sebanyak 3639
# - Dan produk yang paling sedikit dicari adalah **cds dvds musicais** sebanyak 1

# %% [markdown]
# **Menyimpan Berkas**

# %%
all_dataset.to_csv("all_dataset.csv", index=False)
